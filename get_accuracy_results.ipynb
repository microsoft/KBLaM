# %%
from experiments.eval import eval_accuracy
from transformers import AutoTokenizer, logging
from kblam.kb_encoder import KBEncoder
from kblam.models.kblam_config import KBLaMConfig
from kblam.models.llama3_model import KblamLlamaForCausalLM
from kblam.models.phi3_model import KBLaMPhi3ForCausalLM
from kblam.utils.data_utils import aug_row, generate_multi_entity_qa
from kblam.utils.train_utils import get_kb_embd
import os
import torch
import json
import numpy as np
from datetime import datetime

class ResultsCollector():
    def __init__(
            self,
            dataset_dir,
            encoder_path,
            encoder_spec,
            llm_base_dir,
            llm_type,
            model_path,
            query_head_path,
            test_dataset,
            scale_factor=None,
            kb_layer_frequency=-1):
        self.dataset_dir = dataset_dir
        self.encoder_path = encoder_path
        self.encoder_spec = encoder_spec
        self.llm_base_dir = llm_base_dir
        self.llm_type = llm_type
        self.model_path = model_path
        self.query_head_path = query_head_path
        self.test_dataset = test_dataset
        self.scale_factor = scale_factor

        encoder_model_spec = encoder_spec

        validation_part_start_idx = 120000 if "gpt" in test_dataset else 0
        self.dataset = json.load(open(os.path.join(dataset_dir, test_dataset) + "_augmented.json"))[validation_part_start_idx: ]

        self.key_embds = np.load(
            os.path.join(dataset_dir, f"{test_dataset}_{encoder_model_spec}_embd_key.npy")
        ).astype("float32")[validation_part_start_idx: ]
        self.value_embds = np.load(
            os.path.join(dataset_dir, f"{test_dataset}_{encoder_model_spec}_embd_value.npy")
        ).astype("float32")[validation_part_start_idx: ]

        if kb_layer_frequency == -1:
            kb_layer_frequency = 3

        self.tokenizer = AutoTokenizer.from_pretrained(llm_base_dir, trust_remote_code=True, padding_side="left")
        self.tokenizer.pad_token = "^"

        if llm_type == "llama3":
            if query_head_path:
                self.model = KblamLlamaForCausalLM.from_pretrained(
                    model_path,
                    device_map="cuda",
                    torch_dtype="auto",
                    trust_remote_code=True,
                )
                self.model.load_query_head(query_head_path)
            else:
                self.model = KblamLlamaForCausalLM.from_pretrained(
                    model_path,
                    device_map="cuda",
                    torch_dtype="auto",
                    trust_remote_code=True,
                )
        else:
            self.model = KBLaMPhi3ForCausalLM.from_pretrained(
                model_path,
                device_map="cuda",
                torch_dtype="auto",
                trust_remote_code=True,
            )

        self.model.generation_config.pad_token_id = self.tokenizer.pad_token_id
        self.model.generation_config.eos_token_id = 128009
        self.model.eval()


        self.kb_config = KBLaMConfig(
            sep_query_head=True,
            kb_layer_frequency=kb_layer_frequency,
            kb_scale_factor=self.scale_factor,
            **self.model.config.to_dict(),
        )

        print(self.kb_config)

        # self.kb_config = KBLaMConfig.from_pretrained(os.path.join(model_path, "kb_config.json"))
        # self.kb_config.update(**self.model.config.to_dict())

        self.model.config = self.kb_config

        print(self.model.config)

        self.encoder = KBEncoder(
            encoder_name=encoder_spec.upper(),
            projector_type="linear",
            endpoint_url="",
            out_dim=self.model.config.hidden_size * (self.model.config.num_hidden_layers // kb_layer_frequency + 1),
            frozen_base_model=True,
            projector_kwargs={"mlp_depth": 1, "mlp_hidden_dim": 512},
            device=torch.device("cuda"),
        )

        self.encoder.load_state_dict(torch.load(encoder_path))


    def collect_results(self):
        xs = [50, 100, 200, 400, 800] #, 1600, 3200, 6400]
        for x in xs:
            for trial in range(5):
                trial_start_time = datetime.now()
                # experiment_name = f"test_synthetic_scale_factor_validation_only_100_{x}_triples_{trial}_trial"
                #experiment_name = f"nq_10000_scale_factor_100_{x}_triples_{trial}_trial"
                experiment_name = f"test_syntehtic_llama1B_2000_{x}_triples_{trial}_trial"
                print(f"starting {experiment_name}")
                eval_accuracy(
                    dataset_dir=self.dataset_dir,
                    test_dataset=self.test_dataset,
                    encoder_spec=self.encoder_spec,
                    kb_scale_factor=self.scale_factor,
                    encoder_path=self.encoder_path,
                    exp_config=experiment_name,
                    fancy_question=False,
                    kb_layer_frequency=3,
                    kb_size=x,
                    llm_base_dir=self.llm_base_dir,
                    llm_type="llama3",
                    model_path=self.model_path,
                    test_batch_size=min(x, 200),
                    use_shift_match=False,
                    query_head_path=self.query_head_path,
                    save_dir="/home/lmikaelyan/kblam_attention/save_dir",
                    attn_save_dir="/home/lmikaelyan/kblam_attention/attention",
                    model=self.model,
                    dataset=self.dataset,
                    key_embds=self.key_embds,
                    value_embds=self.value_embds,
                    tokenizer=self.tokenizer,
                    encoder=self.encoder,
                    kb_config=self.kb_config,
                )
                print(f"Took {datetime.now() - trial_start_time}")

# %%
# dataset_dir = "/home/t-isazawat/kblam_rebuttal_files/synthetic_perturbed"
# test_dataset = "synthetic_perturbed"
# model_dir = "/home/t-isazawat/azure-blob/xi-kb-llm/llama3_8b_ins"
# base_dir = "/home/t-isazawat/azure-blob/xi-kb-llm/llama3_8b_ins"
# query_head_path = "/home/t-isazawat/azure-blob/xi-kb-llm/best_ckpt/learned_query_head_20000_OAI.pth"
# encoder_path = "/home/t-isazawat/azure-blob/xi-kb-llm/best_ckpt/encoder_ckpt_20000_OAI.pt"

# dataset_dir = "/home/t-isazawat/kblam_rebuttal_files/nq_10000"
# test_dataset = "nq_10000"
# model_dir = "/home/t-isazawat/azure-blob/xi-kb-llm/llama3_8b_ins"
# base_dir = "/home/t-isazawat/azure-blob/xi-kb-llm/llama3_8b_ins"
# query_head_path = "/home/t-isazawat/azure-blob/xi-kb-llm/best_ckpt/learned_query_head_20000_OAI.pth"
# encoder_path = "/home/t-isazawat/azure-blob/xi-kb-llm/best_ckpt/encoder_ckpt_20000_OAI.pt"

dataset_dir = "/home/lmikaelyan/KBLaM/synthetic_data"
test_dataset = "synthetic_data"
model_dir = "/home/lmikaelyan/KBLaM/llama1B-Instruct/stage1_lr_0.0001KBTokenLayerFreq3UseExtendedQAMultiEntities2KBSizedynamicSepQueryHeadKeyFromkey_OAI_synthetic_data_llama3_step_2000"
base_dir = "meta-llama/Llama-3.2-1B-Instruct"
#query_head_path = "/home/t-isazawat/azure-blob/xi-kb-llm/best_ckpt/learned_query_head_20000_OAI.pth"
encoder_path = "/home/lmikaelyan/KBLaM/llama1B-Instruct/stage1_lr_0.0001KBTokenLayerFreq3UseExtendedQAMultiEntities2KBSizedynamicSepQueryHeadKeyFromkey_OAI_synthetic_data_llama3_step_2000/encoder.pt"

collector = ResultsCollector(
    dataset_dir,
    encoder_path,
    "oai",
    model_path=model_dir,
    llm_type="llama3",
    llm_base_dir=base_dir,
    query_head_path=None,
    test_dataset=test_dataset,
    scale_factor=100
)
# Out:
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# KBLaMConfig {
#   "_attn_implementation_autoset": true,
#   "_name_or_path": "/home/lmikaelyan/KBLaM/llama1B-Instruct/stage1_lr_0.0001KBTokenLayerFreq3UseExtendedQAMultiEntities2KBSizedynamicSepQueryHeadKeyFromkey_OAI_synthetic_data_llama3_step_2000",
#   "architectures": [
#     "KblamLlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "attn_implementation": "eager",
#   "base_model_name_or_path": "",
#   "bos_token_id": 128000,
#   "dynamic_sparsify": false,
#   "eos_token_id": [
#     128001,
#     128008,
#     128009
#   ],
#   "head_dim": 64,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "initializer_range": 0.02,
#   "intermediate_size": 8192,
#   "kb_layer_frequency": 3,
#   "kb_scale_factor": 100,
#   "max_position_embeddings": 131072,
#   "mlp_bias": false,
#   "num_attention_heads": 32,
#   "num_hidden_layers": 16,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": {
#     "factor": 32.0,
#     "high_freq_factor": 4.0,
#     "low_freq_factor": 1.0,
#     "original_max_position_embeddings": 8192,
#     "rope_type": "llama3"
#   },
#   "rope_theta": 500000.0,
#   "sep_query_head": true,
#   "top_k_kb": 100,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.46.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 22
#      19 #query_head_path = "/home/t-isazawat/azure-blob/xi-kb-llm/best_ckpt/learned_query_head_20000_OAI.pth"
#      20 encoder_path = "/home/lmikaelyan/KBLaM/llama1B-Instruct/stage1_lr_0.0001KBTokenLayerFreq3UseExtendedQAMultiEntities2KBSizedynamicSepQueryHeadKeyFromkey_OAI_synthetic_data_llama3_step_2000/encoder.pt"
# ---> 22 collector = ResultsCollector(
#      23     dataset_dir,
#      24     encoder_path,
#      25     "oai",
#      26     model_path=model_dir,
#      27     llm_type="llama3",
#      28     llm_base_dir=base_dir,
#      29     query_head_path=None,
#      30     test_dataset=test_dataset,
#      31     scale_factor=100
#      32 )
#
# Cell In[7], line 97, in ResultsCollector.__init__(self, dataset_dir, encoder_path, encoder_spec, llm_base_dir, llm_type, model_path, query_head_path, test_dataset, scale_factor, kb_layer_frequency)
#      92 print(kb_config)
#      94 # self.kb_config = KBLaMConfig.from_pretrained(os.path.join(model_path, "kb_config.json"))
#      95 # self.kb_config.update(**self.model.config.to_dict())
# ---> 97 self.model.config = self.kb_config
#      99 print(self.model.config)
#     101 self.encoder = KBEncoder(
#     102     encoder_name=encoder_spec.upper(),
#     103     projector_type="linear",
#    (...)
#     108     device=torch.device("cuda"),
#     109 )
#
# AttributeError: 'ResultsCollector' object has no attribute 'kb_config'

# %%
collector.collect_results()
# Out:
# starting test_syntehtic_llama1B_2000_50_triples_0_trial
# /home/lmikaelyan/kblam_env/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:774: UserWarning: `return_dict_in_generate` is NOT set to `True`, but `output_attentions` is. When `return_dict_in_generate` is not `True`, `output_attentions` is ignored.
#   warnings.warn(
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# ['^^^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of Fermi Finance?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The description of Fermi Finance is a platform that offers financial planning and investment management tools to help individuals achieve their financial goals and achieve financial stability.<|eot_id|>^^^^^^^^^^^^^^^^^^', '^^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the purpose of ChordChime?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The purpose of ChordChime is to provide a clear and powerful sound for home music, ensuring clear and consistent sound quality for music enthusiasts.<|eot_id|>^^^^^^^^^^^^^^^^^^', '^^^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of Deep House Gospel?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The description of Deep House is a genre of electronic music characterized by deep, soulful melodies and often featuring deep basslines, creating a deep, resonant sound.<|eot_id|>^^^^^^^^^^^^^^', '^^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the purpose of UrbanUtopia?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The purpose of UrbanUtopia is to provide a comprehensive platform for managing and managing urban planning and development projects.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^', '^^^^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the objectives of Index Imp?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The objectives of Index Imp are to provide advanced data analytics tools for data analysis, enhance business insights, and support business decision-making.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^', '^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the purpose of WildWhisker Wonders?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The purpose of WildWhisker Wonders is to promote healthy skin and improve skin health.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^^^^^', '^^^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the objectives of Phi Zenith?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The objectives of Phi Zenith are to provide advanced, high-quality audio solutions for music enthusiasts and professional musicians, and to promote the development of new musical styles.<|eot_id|>^^^^^^^^^^^^^^^', '^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the purpose of Elevation Esplanade?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The purpose of Elevation Esplanade is to promote environmental conservation and preservation of natural habitats, providing a serene and natural environment for recreation and relaxation.<|eot_id|>^^^^^^^^^^^^^^^^^', '^^^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of HoloGrid?<|eot_id|><|start_header_id|>assistant<|end_header_id|> There is no specific description available for HoloGrid.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^', "^^^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the purpose of Caesar's Silk?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The purpose of Caesar's Silk is to provide high-quality, high-performance fabrics for the fashion industry.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^^^^"]
# ACC & TOP 5 ACC: [(np.float64(0.02), np.float64(0.1)), (np.float64(0.02), np.float64(0.1)), (np.float64(0.02), np.float64(0.1)), (np.float64(0.02), np.float64(0.1)), (np.float64(0.02), np.float64(0.1)), (np.float64(0.02), np.float64(0.1))]
# Took 0:00:02.933697
# starting test_syntehtic_llama1B_2000_50_triples_1_trial
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# /home/lmikaelyan/kblam_env/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:774: UserWarning: `return_dict_in_generate` is NOT set to `True`, but `output_attentions` is. When `return_dict_in_generate` is not `True`, `output_attentions` is ignored.
#   warnings.warn(
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# ['^^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of Crystal Surge?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The description of Crystal Surge is a high-energy, high-speed propulsion system for advanced spacecraft.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^^^^^', '^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the objectives of Tagnium?<|eot_id|><|start_header_id|>assistant<|end_header_id|> There is no specific information available on the objectives of Tagnium. If you could provide more details on the objectives, I would be able to provide more information.<|eot_id|>^^^^^^^^^^^^^', '^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of Isabella de la Cruz?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The description of Isabella de la Cruz is a renowned Spanish Renaissance painter known for her intricate and detailed works, which depict the beauty of the natural world.<|eot_id|>^^^^^^^^^^^^^^^', '^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the objectives of Mercurium?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The objectives of Mercurium are to develop advanced materials for advanced electronics, enhance reliability and efficiency, and support the development of new technologies.<|eot_id|>^^^^^^^^^^^^^^^^^^', '^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of CelluSound?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The description of CelluSound is a premium audio system designed for high-end home theaters, offering crystal-clear sound and precise dynamics.<|eot_id|>^^^^^^^^^^^^^^^^^^^^', '^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the objectives of Octavius Firestorm?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The objectives of Octavius Firestorm are to develop advanced materials for high-performance composites, advance in-space propulsion systems, and enhance space mission success.<|eot_id|>^^^^^^^^^^^^^^^', "^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the objectives of Titan's Reach?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The objectives of Titan's Reach include expanding the knowledge of the solar system, advancing our understanding of celestial bodies, and potentially paving the way for future missions to Mars and the outer planets.<|eot_id|>^^^^^^^^^", '^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the purpose of Lambda Health Systems?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The purpose of Lambda Health Systems is to provide innovative healthcare solutions and support for healthcare professionals to improve patient care and enhance healthcare outcomes.<|eot_id|>^^^^^^^^^^^^^^^^^^^^', '^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the objectives of Symphony of the Sea?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The objectives of Symphony of the Sea are to celebrate the beauty and majesty of the ocean, to promote environmental conservation, and to preserve cultural heritage.<|eot_id|>^^^^^^^^^^^^^^^^', "^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the objectives of Shadowclaw?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The objectives of Shadowclaw are to protect the city from threats, defend the city's interests, and maintain peace and stability.<|eot_id|>^^^^^^^^^^^^^^^^^^^^"]
# ACC & TOP 5 ACC: [(np.float64(0.02), np.float64(0.1)), (np.float64(0.02), np.float64(0.1)), (np.float64(0.02), np.float64(0.1)), (np.float64(0.02), np.float64(0.1)), (np.float64(0.02), np.float64(0.1)), (np.float64(0.02), np.float64(0.1))]
# Took 0:00:01.660307
# starting test_syntehtic_llama1B_2000_50_triples_2_trial
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# ...
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# Using separate query head, getting attn weights
# ['^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of Omicron-Upsilon?<|eot_id|><|start_header_id|>assistant<|end_header_id|> There is no description available for Omicron-Upsilon.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^', '^^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of NeuralNavigator?<|eot_id|><|start_header_id|>assistant<|end_header_id|> There is no description available for NeuralNavigator.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^', '^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of ChordCello?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The ChordCello is a high-end, handcrafted cello. It features a rich, rich sound with a deep bass and clear trebolo.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^', '^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the objectives of Andromeda Assets?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The objectives of Andromeda Assets are to provide high-quality, sustainable, and innovative products and services that promote environmental conservation and eco-friendly practices.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^', '^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the purpose of OceanicWanderer?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The purpose of OceanicWanderer is to provide a comprehensive and interactive travel guide, offering detailed information on destinations, activities, and recommendations for travelers.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^', '^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the objectives of PowerFlex Axle?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The objectives of PowerFlex Axle are to ensure optimal power distribution, maintain precise control, and provide reliable performance.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^', '^^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of Asset Avalanche?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The description of Asset Avalanche is a financial platform that helps users track and manage investments, providing real-time market data and portfolio analytics.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^^^^', '^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of DunwichDiary?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The description of DunwichDiary is a self-help book that offers guidance on achieving personal growth, building confidence, and fostering emotional intelligence.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^^', '^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of Whispering Fen?<|eot_id|><|start_header_id|>assistant<|end_header_id|> There is no description available for Whispering Fen.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^', '^^^^^<|begin_of_text|><|start_header_id|>user<|end_header_id|> What is the description of NanoConcrete?<|eot_id|><|start_header_id|>assistant<|end_header_id|> The description of NanoConcrete is a high-performance concrete with advanced thermal insulation and thermal energy storage capabilities.<|eot_id|>^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 collector.collect_results()
#
# Cell In[1], line 120, in ResultsCollector.collect_results(self)
#     118 experiment_name = f"test_syntehtic_llama1B_2000_{x}_triples_{trial}_trial"
#     119 print(f"starting {experiment_name}")
# --> 120 eval_accuracy(
#     121     dataset_dir=self.dataset_dir,
#     122     test_dataset=self.test_dataset,
#     123     encoder_spec=self.encoder_spec,
#     124     kb_scale_factor=self.scale_factor,
#     125     encoder_path=self.encoder_path,
#     126     exp_config=experiment_name,
#     127     fancy_question=False,
#     128     kb_layer_frequency=3,
#     129     kb_size=x,
#     130     llm_base_dir=self.llm_base_dir,
#     131     llm_type="llama3",
#     132     model_path=self.model_path,
#     133     test_batch_size=min(x, 200),
#     134     use_shift_match=False,
#     135     query_head_path=self.query_head_path,
#     136     save_dir="/home/lmikaelyan/kblam_attention/save_dir",
#     137     attn_save_dir="/home/lmikaelyan/kblam_attention/attention",
#     138     model=self.model,
#     139     dataset=self.dataset,
#     140     key_embds=self.key_embds,
#     141     value_embds=self.value_embds,
#     142     tokenizer=self.tokenizer,
#     143     encoder=self.encoder,
#     144 )
#     145 print(f"Took {datetime.now() - trial_start_time}")
#
# File ~/KBLaM/experiments/eval.py:836, in eval_accuracy(dataset_dir, encoder_path, encoder_spec, exp_config, fancy_question, kb_layer_frequency, kb_scale_factor, kb_size, llm_base_dir, llm_type, model_path, test_batch_size, test_dataset, use_shift_match, query_head_path, save_dir, attn_save_dir, model, dataset, key_embds, value_embds, tokenizer, encoder, use_mlflow)
#     834 label = np.arange(test_batch_size)
#     835 weight = weight.reshape(test_batch_size, -1, kb_size)
# --> 836 np.save(os.path.join(attn_save_dir, f"{exp_config}_{idx}_debug.npy"), weight)
#     838 acc = (weight.sum(1).argmax(1) == label).mean()
#     839 top_5_predictions = torch.topk(torch.from_numpy(weight.sum(1)), 5, dim=1)[1]
#
# File ~/kblam_env/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:587, in save(file, arr, allow_pickle, fix_imports)
#     585 with file_ctx as fid:
#     586     arr = np.asanyarray(arr)
# --> 587     format.write_array(fid, arr, allow_pickle=allow_pickle,
#     588                        pickle_kwargs=dict(fix_imports=fix_imports))
#
# File ~/kblam_env/lib/python3.10/site-packages/numpy/lib/format.py:757, in write_array(fp, array, version, allow_pickle, pickle_kwargs)
#     755 else:
#     756     if isfileobj(fp):
# --> 757         array.tofile(fp)
#     758     else:
#     759         for chunk in numpy.nditer(
#     760                 array, flags=['external_loop', 'buffered', 'zerosize_ok'],
#     761                 buffersize=buffersize, order='C'):
#
# KeyboardInterrupt:

# %%
# !pip install seaborn
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 3.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pandas>=1.2 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: pillow>=8 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.0)
# Requirement already satisfied: packaging>=20.0 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pytz>=2020.1 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/lmikaelyan/kblam_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

def create_normalized_heatmap(data, output_file='heatmap.png', figsize=(10, 8)):
    # Normalize data to 0-1 range
    print(data.shape)
    normalized_data = (data - np.min(data)) / (np.max(data) - np.min(data))


    # Create heatmap
    plt.figure(figsize=figsize)
    sns.heatmap(normalized_data, 
                cmap='YlOrRd',
                cbar_kws={'label': 'Normalized Value'},
                xticklabels=True,
                yticklabels=True)

    plt.tight_layout()
    plt.savefig(output_file, dpi=300, bbox_inches='tight')
    plt.close()

attention_weights = np.load("/home/lmikaelyan/kblam_attention/attention/test_syntehtic_llama1B_2000_100_triples_4_trial_6_debug.npy")

print(attention_weights.shape)

print(np.sum(attention_weights, axis=1).shape)

create_normalized_heatmap(np.argmax(attention_weights, axis=1))
# Out:
# (100, 672, 100)
# (100, 100)
# (100, 100)

# %%
attention_weights = np.load("/home/lmikaelyan/kblam_attention/attention/test_syntehtic_llama1B_2000_100_triples_3_trial_0_debug.npy")

# %%
test_batch_size = 100

# %%
label = np.arange(test_batch_size)

# %%
attention_weights.shape
# Out:
# (100, 704, 100)

# %%
original_weight = np.load("/home/lmikaelyan/kblam_attention/attention/test_syntehtic_llama1B_2000_100_triples_3_trial_0.npy")

# %%
original_weight.shape
# Out:
# (100, 32, 22, 122)

# %%
original_weight = original_weight[..., :100]
weight = original_weight.reshape(100, -1, 100).sum(1)
weight.shape
# Out:
# (100, 100)

# %%
original_weight
# Out:
# array([[[[8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          ...,
#          [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#           0.0000000e+00, 1.0000000e+00, 0.0000000e+00],
#          [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#           0.0000000e+00, 1.0000000e+00, 0.0000000e+00]],
#
#         [[8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          ...,
#          [2.5177002e-03, 2.5177002e-03, 2.5177002e-03, ...,
#           2.5177002e-03, 2.5177002e-03, 2.5177002e-03],
#          [3.5552979e-03, 3.5552979e-03, 3.5552979e-03, ...,
#           3.5552979e-03, 3.5552979e-03, 3.5552979e-03],
#          [1.9836426e-03, 1.9836426e-03, 1.9836426e-03, ...,
#           1.9836426e-03, 1.9836426e-03, 1.9836426e-03]],
#
#         [[8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          ...,
#          [3.7574768e-04, 3.7574768e-04, 3.7574768e-04, ...,
#           3.7574768e-04, 3.7574768e-04, 3.7574768e-04],
#          [6.3323975e-04, 6.3323975e-04, 6.3323975e-04, ...,
#           6.3323975e-04, 6.3323975e-04, 6.3323975e-04],
#          [1.0528564e-03, 1.0528564e-03, 1.0528564e-03, ...,
#           1.0528564e-03, 1.0528564e-03, 1.0528564e-03]],
#
#         ...,
#
#         [[8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          ...,
#          [2.7618408e-03, 2.7618408e-03, 2.7618408e-03, ...,
#           2.7618408e-03, 2.7618408e-03, 2.7618408e-03],
#          [2.9602051e-03, 2.9602051e-03, 2.9602051e-03, ...,
#           2.9602051e-03, 2.9602051e-03, 2.9602051e-03],
#          [1.8920898e-03, 1.8920898e-03, 1.8920898e-03, ...,
#           1.8920898e-03, 1.8920898e-03, 1.8920898e-03]],
#
#         [[8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          ...,
#          
#
#         [[8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          ...,
#          [2.7618408e-03, 2.7618408e-03, 2.7618408e-03, ...,
#           2.7618408e-03, 2.7618408e-03, 2.7618408e-03],
#          [2.9449463e-03, 2.9449463e-03, 2.9449463e-03, ...,
#           2.9449463e-03, 2.9449463e-03, 2.9449463e-03],
#          [1.8844604e-03, 1.8844604e-03, 1.8844604e-03, ...,
#           1.8844604e-03, 1.8844604e-03, 1.8844604e-03]],
#
#         [[8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          ...,
#          [5.7983398e-03, 5.7983398e-03, 5.7983398e-03, ...,
#           5.7983398e-03, 5.7983398e-03, 5.7983398e-03],
#          [4.6691895e-03, 4.6691895e-03, 4.6691895e-03, ...,
#           4.6691895e-03, 4.6691895e-03, 4.6691895e-03],
#          [5.0048828e-03, 5.0048828e-03, 5.0048828e-03, ...,
#           5.0048828e-03, 5.0048828e-03, 5.0048828e-03]],
#
#         [[8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          [8.1787109e-03, 8.1787109e-03, 8.1787109e-03, ...,
#           8.1787109e-03, 8.1787109e-03, 8.1787109e-03],
#          ...,
#          [3.6468506e-03, 3.6468506e-03, 3.6468506e-03, ...,
#           3.6468506e-03, 3.6468506e-03, 3.6468506e-03],
#          [3.3569336e-03, 3.3569336e-03, 3.3569336e-03, ...,
#           3.3569336e-03, 3.3569336e-03, 3.3569336e-03],
#          [2.3651123e-03, 2.3651123e-03, 2.3651123e-03, ...,
#           2.3651123e-03, 2.3651123e-03, 2.3651123e-03]]]], dtype=float32)

# %%
dataset = json.load(open(os.path.join(dataset_dir, test_dataset + "_augmented.json")))

# %%
for data in dataset:
    if "University" in data["name"]:
        print(data)
# Out:
# {'name': 'Nyarlathotep University', 'description_type': 'description', 'description': 'a leading institution in biomedical engineering and healthcare innovation', 'Q': 'What is the description of Nyarlathotep University?', 'A': 'The description of Nyarlathotep University is a leading institution in biomedical engineering and healthcare innovation.', 'key_string': 'the description of Nyarlathotep University', 'extended_Q': 'What can you tell me about the description characteristics of Nyarlathotep University and what makes it stand out in its field?', 'extended_A': 'The description of Nyarlathotep University is a leading institution in biomedical engineering and healthcare innovation. What makes it stand out in its field is its pioneering research, cutting-edge technology, and a strong emphasis on interdisciplinary collaboration, which collectively contribute to significant advancements in medical science and patient care.'}
# {'name': 'Nyarlathotep University', 'description_type': 'objectives', 'description': 'to drive advancements in medical technology and patient care', 'Q': 'What is the objectives of Nyarlathotep University?', 'A': 'The objectives of Nyarlathotep University is to drive advancements in medical technology and patient care.', 'key_string': 'the objectives of Nyarlathotep University', 'extended_Q': 'Can you inform me about the objectives of Nyarlathotep University and what do you think of its focus on medical technology and patient care?', 'extended_A': 'The objectives of Nyarlathotep University is to drive advancements in medical technology and patient care. Focusing on these areas is crucial as it can lead to significant improvements in healthcare outcomes, enhance the quality of life for patients, and potentially lead to groundbreaking innovations in medical science.'}
# {'name': 'Nyarlathotep University', 'description_type': 'purpose', 'description': 'to improve health outcomes and quality of life through innovation', 'Q': 'What is the purpose of Nyarlathotep University?', 'A': 'The purpose of Nyarlathotep University is to improve health outcomes and quality of life through innovation.', 'key_string': 'the purpose of Nyarlathotep University', 'extended_Q': 'What is the purpose of Nyarlathotep University and how does it aim to achieve this goal?', 'extended_A': 'The purpose of Nyarlathotep University is to improve health outcomes and quality of life through innovation. It aims to achieve this goal by fostering an environment that encourages innovative research, developing cutting-edge technologies, and implementing new methodologies in healthcare and related fields.'}
# {'name': 'Universe University', 'description_type': 'description', 'description': 'explore the potential of algae as a biofuel source', 'Q': 'What is the description of Universe University?', 'A': 'The description of Universe University is explore the potential of algae as a biofuel source.', 'key_string': 'the description of Universe University', 'extended_Q': 'Provide details on the description of Universe University and what is its primary research focus?', 'extended_A': 'The description of Universe University is explore the potential of algae as a biofuel source. Its primary research focus is on investigating how algae can be utilized as a sustainable and efficient source of biofuel.'}
# {'name': 'Universe University', 'description_type': 'objectives', 'description': 'cultivate algae, extract biofuels, and analyze energy efficiency', 'Q': 'What is the objectives of Universe University?', 'A': 'The objectives of Universe University is cultivate algae, extract biofuels, and analyze energy efficiency.', 'key_string': 'the objectives of Universe University', 'extended_Q': 'What insights can you provide about the objectives of Universe University and what do you think of them?', 'extended_A': 'The objectives of Universe University are to cultivate algae, extract biofuels, and analyze energy efficiency. These objectives are forward-thinking and align well with current global efforts to find sustainable and renewable energy sources. By focusing on algae cultivation and biofuel extraction, the university is contributing to the development of alternative energy solutions that could reduce dependence on fossil fuels. Additionally, analyzing energy efficiency is crucial for optimizing these processes and ensuring that they are both economically and environmentally viable. Overall, these objectives demonstrate a strong commitment to innovation and sustainability in the energy sector.'}
# {'name': 'Universe University', 'description_type': 'purpose', 'description': 'to develop sustainable energy alternatives and reduce carbon emissions', 'Q': 'What is the purpose of Universe University?', 'A': 'The purpose of Universe University is to develop sustainable energy alternatives and reduce carbon emissions.', 'key_string': 'the purpose of Universe University', 'extended_Q': 'What kind of purpose does Universe University have, and how do they aim to achieve it?', 'extended_A': 'The purpose of Universe University is to develop sustainable energy alternatives and reduce carbon emissions. They aim to achieve this by conducting cutting-edge research in renewable energy technologies, collaborating with industry leaders, and educating the next generation of scientists and engineers in sustainable practices.'}
# {'name': 'Universe University-2', 'description_type': 'description', 'description': 'study the impact of urbanization on local wildlife', 'Q': 'What is the description of Universe University-2?', 'A': 'The description of Universe University-2 is study the impact of urbanization on local wildlife.', 'key_string': 'the description of Universe University-2', 'extended_Q': 'What kind of description does Universe University-2 have and what is the focus of their research?', 'extended_A': 'The description of Universe University-2 is study the impact of urbanization on local wildlife. The focus of their research is to understand how urban development affects the habitats and behaviors of wildlife in the surrounding areas.'}
# {'name': 'Universe University-2', 'description_type': 'objectives', 'description': 'monitor animal populations, analyze habitat use, and develop conservation strategies', 'Q': 'What is the objectives of Universe University-2?', 'A': 'The objectives of Universe University-2 is monitor animal populations, analyze habitat use, and develop conservation strategies.', 'key_string': 'the objectives of Universe University-2', 'extended_Q': 'Tell me about the objectives of Universe University-2 and what do you think of its approach to conservation?', 'extended_A': 'The objectives of Universe University-2 are to monitor animal populations, analyze habitat use, and develop conservation strategies. This approach is comprehensive as it not only focuses on tracking and understanding wildlife but also on creating actionable plans to protect and sustain their habitats. By combining these elements, Universe University-2 is likely to make significant contributions to conservation efforts.'}
# {'name': 'Universe University-2', 'description_type': 'purpose', 'description': 'to protect urban biodiversity and support ecosystem health', 'Q': 'What is the purpose of Universe University-2?', 'A': 'The purpose of Universe University-2 is to protect urban biodiversity and support ecosystem health.', 'key_string': 'the purpose of Universe University-2', 'extended_Q': 'What should I know about the purpose of Universe University-2 and how does it aim to achieve its goals?', 'extended_A': 'The purpose of Universe University-2 is to protect urban biodiversity and support ecosystem health. It aims to achieve its goals by implementing various conservation programs, conducting research on urban ecosystems, and engaging the community in biodiversity-friendly practices.'}

# %%
collector.model
# Out:
# KblamLlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 2048)
#     (layers): ModuleList(
#       (0-15): 16 x LlamaDecoderLayer(
#         (self_attn): KblamLlamaAttention(
#           (q_proj): Linear(in_features=2048, out_features=2048, bias=False)
#           (q_proj_new): Linear(in_features=2048, out_features=2048, bias=False)
#           (k_proj): Linear(in_features=2048, out_features=512, bias=False)
#           (v_proj): Linear(in_features=2048, out_features=512, bias=False)
#           (o_proj): Linear(in_features=2048, out_features=2048, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=2048, out_features=8192, bias=False)
#           (up_proj): Linear(in_features=2048, out_features=8192, bias=False)
#           (down_proj): Linear(in_features=8192, out_features=2048, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((2048,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=2048, out_features=128256, bias=False)
# )

# %%
len(collector.dataset)
# Out:
# 132072

# %%
os.environ['SEP_QUERY_HEAD'] = 'TRUE'
os.environ['LENGTH_INVARIANCE'] = ''
# os.environ['SEP_QUERY_HEAD'] = ''
encoder_model_spec = 'OAI'
# train_dataset_name = 'avocado_new'
train_dataset_name = 'gpt_data'
epoch = 10000
# lr = 0.0005
lr = 0.0001
extended_qa_spec = 'UseExtendedQA'
outlier_spec = "UseOutlier1"
# outlier_spec = ""
multi_entity_string = "MultiEntities2"
# multi_entity_string = ""
# outlier_spec = ""
kb_size_spec = 'KBSizedynamic'
# kb_size_spec = 'KBSize50'
# os.environ['SCALE_FACTOR'] = '40'
os.environ['SCALE_FACTOR'] = ''
duplicate_spec = "NoDuplicate"
kb_layer_frequency = 1
kb_layer_frequency_str = f'KBTokenLayerFreq{kb_layer_frequency}'
# kb_layer_frequency_str=''
# outlier_spec = ''
key_src = 'key'

llm_model_spec = '/home/t-wangx/llama_weights/llama3_8b_ins'
print(f'/home/t-wangx/azure_blob/xi-kb-llm/outputs/ckpts/stage1_0__lr_{lr}{kb_layer_frequency_str}{extended_qa_spec}{multi_entity_string}{outlier_spec}{duplicate_spec}{kb_size_spec}SepQueryHeadUseDataAugKeyFrom{key_src}_{encoder_model_spec}_{train_dataset_name}_llama3_epoch_{epoch}')
print( f'/home/t-wangx/azure_blob/xi-kb-llm/outputs/ckpts/stage1_0__lr_{lr}{kb_layer_frequency_str}{extended_qa_spec}{multi_entity_string}{outlier_spec}{duplicate_spec}{kb_size_spec}SepQueryHeadUseDataAugFineTuneQueryKeyFrom{key_src}_{train_dataset_name}_{encoder_model_spec}_epoch_{epoch}')
# Out:
# /home/t-wangx/azure_blob/xi-kb-llm/outputs/ckpts/stage1_0__lr_0.0001KBTokenLayerFreq1UseExtendedQAMultiEntities2UseOutlier1NoDuplicateKBSizedynamicSepQueryHeadUseDataAugKeyFromkey_OAI_gpt_data_llama3_epoch_10000
# /home/t-wangx/azure_blob/xi-kb-llm/outputs/ckpts/stage1_0__lr_0.0001KBTokenLayerFreq1UseExtendedQAMultiEntities2UseOutlier1NoDuplicateKBSizedynamicSepQueryHeadUseDataAugFineTuneQueryKeyFromkey_gpt_data_OAI_epoch_10000
